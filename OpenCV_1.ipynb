# %%
import numpy as np
import cv2
face_cascade = cv2.CascadeClassifier('C:\\Anaconda3\\pkgs\\opencv3-3.1.0-py35_0\\Library\\etc\\haarcascades\\haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:\\Anaconda3\\pkgs\\opencv3-3.1.0-py35_0\\Library\\etc\\haarcascades\\haarcascade_eye.xml')

# %%
print (face_cascade)
# Out:
# <CascadeClassifier 000001DD52C53D50>

# %%
img = cv2.imread('messi5.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    #eyes = eye_cascade.detectMultiScale(roi_gray)
    #for (ex,ey,ew,eh) in eyes:
    #    cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import csv
import numpy as np
import pandas as pd
from pandas import read_csv

X = read_csv('training.csv') 
A = np.array(X)
A = A[0:,30]
res = []
for i in A:
    res.append([int(x) for x in i.split(' ')])

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
res=np.array(res)
img = res[2].reshape(96,96)
img += 100
plt.imshow(img)
plt.show()

# %%
import scipy.misc
scipy.misc.imsave('outfile.jpg', img)

# %%
import PIL
from PIL import Image

im = PIL.Image.fromarray(res[2].reshape(96,96))
img = im.resize((256,256), PIL.Image.ANTIALIAS)
plt.imshow(img)
plt.show()
print(hsize,basewidth)

#img.save('sompic.jpg')
# Out:
# 256 256
